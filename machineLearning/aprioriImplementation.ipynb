# %% [markdown]
# ## Implementación de a priori
# Adrián García López
# A01351166

# %% [markdown]
# ## Dataset
# El dataset escogido, es el de mis propias listas de super. La finalidad es la de predecir que productos pediré o tendré que pedir durante mi próximo super y de esta manera eficientizar mis compras de super. Los productos comprados son consumidos por dos personas. Y cada super es pedido aproximadamente cada quincena.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)
from mlxtend.preprocessing import TransactionEncoder
import sys
import numpy as np
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# Se usará 0.4 como soporte minimo para este dataset

# %%
minimum_support = 0.4
transactions = [['parmesano', 'yoghurt', 'leche', 'milanesa', 'carne', 'aceite', 'pasta', 'tomate', 'cereal', 'zanahoria', 'papa', 'cerveza'],
                ['arroz', 'chilorio', 'frijoles', 'parmesano', 'cereal', 'jugo', 'durazno', 'pasta', 'tomate', 'carne', 'uva', 'yoghurt', 'harina', 'miel', 'milanesa', 'insecticida'],
                ['huevo', 'leche', 'parmesano', 'milanesa', 'oregano', 'carne', 'limon', 'jugo', 'salchicha', 'bicarbonato', 'azucar', 'cocoa', 'cacao', 'cereal', 'palomitas', 'esponja', 'avellana', 'tostadas', 'mango', 'manzana', 'levadura', 'sacapuntas'],
                ['refresco', 'agua', 'servilletas', 'pinzas', 'leche', 'crema', 'cafe', 'colador', 'huevo', 'azucar', 'yoghurt', 'vainilla', 'chispas', 'lavatrastes', 'harina', 'hisopos', 'pure', 'canela'],
                ['leche', 'pasta', 'tomate', 'refresco', 'pimienta', 'servilletas', 'milanesa', 'cilantro', 'jugo', 'pepino', 'cebolla', 'pan', 'tomillo', 'mejorana', 'caldo', 'arroz', 'papa', 'cereal', 'yoghurt', 'palillos', 'mozarella', 'jabon', 'carne'],
                ['huevo', 'leche', 'refresco', 'parmesano', 'silicon', 'jugo', 'cafe'],
                ['leche', 'parmesano', 'cereal', 'pan', 'zanahoria', 'chayote', 'papa', 'crema', 'bbq', 'limon', 'manzana'],
                ['leche', 'jamon', 'tomate', 'totopos', 'asadero', 'galletas', 'pasta', 'refresco'],
                ['huevo', 'mantequilla', 'pasta', 'jugo', 'leche', 'parmesano', 'refresco', 'manzana', 'servilletas', 'cereal', 'hisopos'],
                ['tomate', 'pasta', 'pan', 'leche', 'zanahoria', 'papa', 'chayote', 'chilorio', 'frijoles', 'milanesa', 'carne', 'aceite', 'yoghurt']]

# %%
from mlxtend.frequent_patterns import apriori

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    aceite   agua  arroz  asadero  avellana  azucar    bbq  bicarbonato  cacao  \
# 0    True  False  False    False     False   False  False        False  False
# 1   False  False   True    False     False   False  False        False  False
# 2   False  False  False    False      True    True  False         True   True
# 3   False   True  False    False     False    True  False        False  False
# 4   False  False   True    False     False   False  False        False  False
# 5   False  False  False    False     False   False  False        False  False
# 6   False  False  False    False     False   False   True        False  False
# 7   False  False  False     True     False   False  False        False  False
# 8   False  False  False    False     False   False  False        False  False
# 9    True  False  False    False     False   False  False        False  False
#
#     cafe  caldo  canela  carne  cebolla  cereal  cerveza  chayote  chilorio  \
# ...

# %%
frequent_itemsets = apriori(df, min_support=minimum_support, use_colnames=True)
frequent_itemsets['iteracion'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
np.set_printoptions(threshold=np.inf)
frequent_itemsets
# Out:
#     support                                   itemsets  iteracion
# 0       0.5                                    (carne)          1
# 1       0.6                                   (cereal)          1
# 2       0.4                                    (huevo)          1
# 3       0.5                                     (jugo)          1
# 4       0.9                                    (leche)          1
# 5       0.5                                 (milanesa)          1
# 6       0.4                                     (papa)          1
# 7       0.6                                (parmesano)          1
# 8       0.6                                    (pasta)          1
# 9       0.5                                 (refresco)          1
# 10      0.5                                   (tomate)          1
# 11      0.5                                  (yoghurt)          1
# 12      0.4                            (cereal, carne)          2
# ...

# %% [markdown]
# # Conclusiones

# %% [markdown]
# ### Productos más comprados
# Se puede apreciar que el producto más comprado es leche, siendo esta, comprada el 90% de las ocasiones. Por otro lado, el queso parmesano, cereal y pasta son comprados en el 60% de los pedidos.

# %% [markdown]
# ### Combinaciones destacadas
#
# - Carne y milanesa: Estos dos productos son usados en muchos platillos, por lo que es lógico pensar por qué están correlacionados
# - Leche y cereal: Combinación un poco lógica
# - Pasta y Tomate: Para hacer pasta de tomate
# - Pasta, Tomate, Yoghurt, Milanesa, Carne: Esta fue la última iteración lograda y se pide en un 40% de las ocasiones. Es una interesante sublista para empezar cada vez que se haga super

# %% [markdown]
# ### Observaciones
# Por lo menos el 40% de mis pedidos de super tienen carbohidratos y proteínas de forma balanceada... Y aun así tengo sobrepeso, ¿por qué sucede esto? No tengo ni idea...
